# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sb                       # to visualize
import pandas as pd                         # for data reading
import numpy as np  
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data (2).csv")
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %%
print(df.shape)
# Out:
# (100000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
df['NAME_TYPE_SUITE'].unique()
# Out:
# array(['Unaccompanied', 'Family', 'Spouse, partner', 'Children',
#        'Other_A', nan, 'Other_B', 'Group of people'], dtype=object)

# %%
a= df.select_dtypes(exclude='object')
a
# Out:
#        SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0          100002       1             0          202500.0    406597.5
# 1          100003       0             0          270000.0   1293502.5
# 2          100004       0             0           67500.0    135000.0
# 3          100006       0             0          135000.0    312682.5
# 4          100007       0             0          121500.0    513000.0
# ...           ...     ...           ...               ...         ...
# 99995      216086       0             1          157500.0    755190.0
# 99996      216087       0             1          225000.0    284400.0
# 99997      216088       0             0          135000.0   1262583.0
# 99998      216089       0             0          135000.0    225000.0
# 99999      216090       0             0          202500.0    337500.0
#
#        AMT_GOODS_PRICE  DAYS_EMPLOYED  MOBILE  WORK_PHONE  HOME_PHONE  \
# ...

# %%
b= df.select_dtypes(include='object')
b
# Out:
#       NAME_CONTRACT_TYPE GENDER Car House NAME_TYPE_SUITE  \
# 0             Cash loans      M   N     Y   Unaccompanied
# 1             Cash loans      F   N     N          Family
# 2        Revolving loans      M   Y     Y   Unaccompanied
# 3             Cash loans      F   N     Y   Unaccompanied
# 4             Cash loans      M   N     Y   Unaccompanied
# ...                  ...    ...  ..   ...             ...
# 99995         Cash loans      F   N     Y   Unaccompanied
# 99996         Cash loans      F   N     Y   Unaccompanied
# 99997         Cash loans      F   Y     Y          Family
# 99998         Cash loans      F   Y     N   Unaccompanied
# 99999    Revolving loans      M   Y     Y   Unaccompanied
#
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                   Working  Secondary / secondary special
# 1             State servant               Higher education
# 2                   Working  Secondary / secondary special
# ...

# %%
a_lst=[a.columns]
b_lst=[b.columns]

# %%
print(tabulate({"Categorical":b_lst,"Continuous":a_lst},headers=['Categorical','Numerical']))
# Out:
# Categorical                                                                Numerical
# -------------------------------------------------------------------------  --------------------------------------------------------------------
# Index(['NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House', 'NAME_TYPE_SUITE',  Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',           'AMT_CREDIT', 'AMT_GOODS_PRICE', 'DAYS_EMPLOYED', 'MOBILE',
#        'OCCUPATION_TYPE', 'APPLICATION_DAY'],                                     'WORK_PHONE', 'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL',
#       dtype='object')                                                             'CNT_FAM_MEMBERS', 'TOTAL_DOC_SUBMITTED'],
#                                                                                  dtype='object')

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe
    if df[col].isnull().sum() > 0:  #` check if null values are present
        print(f"\nThere are null values in the {col} column")

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
b.describe()
# Out:
#        NAME_CONTRACT_TYPE  GENDER     Car   House NAME_TYPE_SUITE  \
# count              100000  100000  100000  100000           99595
# unique                  2       3       2       2               7
# top            Cash loans       F       N       Y   Unaccompanied
# freq                90517   65855   66018   69328           80789
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# count            100000                         100000             100000
# unique                8                              5                  6
# top             Working  Secondary / secondary special            Married
# freq              51902                          71068              64058
#
#        OCCUPATION_TYPE APPLICATION_DAY
# count            68776          100000
# unique              18               7
# top           Laborers         TUESDAY
# freq             17977           17408

# %% [markdown]
# ## Univariate method

# %% [markdown]
# ### Analysis of TARGET:

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of TARGET")                  
percentage = df["TARGET"].value_counts()         
labels = list(df["TARGET"].value_counts().index) 

sb.countplot(x = df["TARGET"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# #### Conclusion: Taarget 0 is highest than Target 1

# %% [markdown]
# ### Analysis of NAME_EDUCATION_TYPE:

# %%
fig, ax = plt.subplots(1, 2, figsize = (25, 7))

ax[0].set_title("Count of NAME_EDUCATION_TYPE")                  
percentage = df["NAME_EDUCATION_TYPE"].value_counts()         
labels = list(df["NAME_EDUCATION_TYPE"].value_counts().index) 

sb.countplot(x = df["NAME_EDUCATION_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# #### Conclusion: There are high no of Secondary/Secondary Special customers

# %% [markdown]
# ### Analysis of OCCUPATION_TYPE

# %%
df["OCCUPATION_TYPE"].fillna("Other", inplace = True)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sb.countplot(x = df["OCCUPATION_TYPE"])
# Out:
# <AxesSubplot:xlabel='OCCUPATION_TYPE', ylabel='count'>

# %% [markdown]
# #### Conclusion: Laborers and others occupation are highest

# %% [markdown]
# ### Analysis of Car:

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sb.countplot(x = df["Car"])
# Out:
# <AxesSubplot:xlabel='Car', ylabel='count'>

# %% [markdown]
# #### Conclusion: Less Car loans have provided

# %% [markdown]
# ### Analysis of House:

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sb.countplot(x = df["House"])
# Out:
# <AxesSubplot:xlabel='House', ylabel='count'>

# %% [markdown]
# #### Conclusion: High amount of House loans are provided

# %% [markdown]
# ### Analysis of AMT_GOODS_PRICE:

# %%
fig, ax = plt.subplots(1, 3, figsize= (20, 7))               
sb.histplot(x = df["AMT_GOODS_PRICE"], ax =ax[1], color = "m") 

sb.kdeplot(x = df["AMT_GOODS_PRICE"], ax = ax[2], shade=True,color = "r")
sb.rugplot(x = df["AMT_GOODS_PRICE"], ax = ax[0], color = "y",height=0.8)
#plt.show()
plt.tight_layout()

# %%
df["AMT_GOODS_PRICE"]=df["AMT_GOODS_PRICE"].fillna(df["AMT_GOODS_PRICE"].mean())

# %%
info_of_numerical('AMT_GOODS_PRICE')
# Out:
# The mean of the AMT_GOODS_PRICE is 538345.1489706668
# The median of the AMT_GOODS_PRICE is 450000.0
# The mode of the AMT_GOODS_PRICE is 450000.0
# The standard deviation of the AMT_GOODS_PRICE is 369248.08675950737
# Number of missing values in the AMT_GOODS_PRICE is 0

# %%
# Making changes in data
mean1 = int(df.AMT_GOODS_PRICE.mean())
x = df[df["AMT_GOODS_PRICE"] >= 500000].index
df.loc[x, "AMT_GOODS_PRICE"] = mean1

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sb.histplot(x = df["AMT_GOODS_PRICE"], ax =ax[1], color = "m") 


sb.rugplot(x = df["AMT_GOODS_PRICE"], ax = ax[0], color = "y",height=0.8)
#plt.show()
plt.tight_layout()

# %% [markdown]
# #### Conclusion: There are more 450000 amt goods price given

# %% [markdown]
# ### Analysis of AMT_INCOME_TOTAL:

# %%
fig, ax = plt.subplots(figsize= (20, 7))               
sb.boxplot(x = df["AMT_INCOME_TOTAL"], color = "r")
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL'>

# %%
info_of_numerical('AMT_INCOME_TOTAL')
# Out:
# The mean of the AMT_INCOME_TOTAL is 169426.07027325002
# The median of the AMT_INCOME_TOTAL is 144000.0
# The mode of the AMT_INCOME_TOTAL is 135000.0
# The standard deviation of the AMT_INCOME_TOTAL is 383500.74427718896
# Number of missing values in the AMT_INCOME_TOTAL is 0

# %%
# Making changes in data
mean1 = int(df.AMT_INCOME_TOTAL.mean())
x = df[df["AMT_INCOME_TOTAL"] >= 135000.0].index
df.loc[x, "AMT_INCOME_TOTAL"] = mean1

# %%
fig, ax = plt.subplots(1, 3, figsize= (20, 7))               
sb.histplot(x = df["AMT_INCOME_TOTAL"], ax =ax[1], color = "m") 

sb.boxplot(x = df["AMT_INCOME_TOTAL"], ax = ax[2])
sb.rugplot(x = df["AMT_INCOME_TOTAL"], ax = ax[0], color = "y",height=0.8)
#plt.show()
plt.tight_layout()

# %% [markdown]
# #### Conclusion:Max total income is above 160000

# %% [markdown]
# ### Analysis of Application Day:

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sb.countplot(x = df["APPLICATION_DAY"])
# Out:
# <AxesSubplot:xlabel='APPLICATION_DAY', ylabel='count'>

# %% [markdown]
# #### Conclusion: High Amount of Application are submitted on Tuesday

# %% [markdown]
# ### Analysis of TOTAL_DOC_SUBMITTED

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=45)
sb.countplot(x = df["TOTAL_DOC_SUBMITTED"])
# Out:
# <AxesSubplot:xlabel='TOTAL_DOC_SUBMITTED', ylabel='count'>

# %% [markdown]
# #### Conclusion: Only Single Document is submitted

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Analysis of House with Application Day

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "APPLICATION_DAY", hue = "House", data = df)
plt.show()

# %% [markdown]
# ### Analysis of Car with Application Day

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "APPLICATION_DAY", hue = "Car", data = df)
plt.show()

# %% [markdown]
# #### Conclusion: High Amount of House owners are there

# %% [markdown]
# ### Analysis of TOTAL_DOC_SUBMITTED with Targets

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "TOTAL_DOC_SUBMITTED", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# #### Conclusion: The single document contains more not payed installments

# %% [markdown]
# ### Analysis with AD with TDS:

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "APPLICATION_DAY", hue = "TOTAL_DOC_SUBMITTED", data = df)
plt.show()

# %% [markdown]
# #### Conclusion: Tuesday Contains more documents submission

# %% [markdown]
# ### Analysis with AD with Target:

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "APPLICATION_DAY", hue = "TARGET", data = df)
plt.show()

# %% [markdown]
# ### Conclusion: On Everyday the Payment irregularities are more

# %% [markdown]
# ### Analysis with AD  and NAME_CONTRACT_TYPE

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sb.countplot(x = "APPLICATION_DAY", hue = "NAME_CONTRACT_TYPE", data = df)
plt.show()

# %% [markdown]
# #### Conclusion: Cash LOans are more than Revolving loans

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ### Analysis of the AD with Targets and Monthly income

# %%
#plt.xticks(rotation=45)
sb.scatterplot(df["AMT_INCOME_TOTAL"],df['APPLICATION_DAY'],df['TARGET'])
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='APPLICATION_DAY'>

# %%
#### Conclusion: There are many irregularities in payment

# %% [markdown]
# ### Analysis of the AD with NAME_CONTRACT_TYPE and TARGET

# %%
sb.scatterplot(df["NAME_CONTRACT_TYPE"],df['APPLICATION_DAY'],df['TARGET'])
# Out:
# <AxesSubplot:xlabel='NAME_CONTRACT_TYPE', ylabel='APPLICATION_DAY'>

# %% [markdown]
# #### Conclusion: CASH and Revolving loans shows high irregularities in payment

# %% [markdown]
# ### Analysis of the NAME_CONTRACT_TYPE with AMT_CREDIT and DAYS_EMPLOYED

# %%
df['DAYS_EMPLOYED'].describe()
# Out:
# count    100000.000000
# mean      63292.222060
# std      140839.697296
# min      -17531.000000
# 25%       -2758.000000
# 50%       -1219.000000
# 75%        -291.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %%
E=df[df['DAYS_EMPLOYED']<150000]

# %%
sb.scatterplot(E["AMT_CREDIT"],E['DAYS_EMPLOYED'],E['NAME_CONTRACT_TYPE'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='DAYS_EMPLOYED'>

# %% [markdown]
# #### Conclusion: High amount of Cash loans have taken

# %% [markdown]
# ### Analysis of the OCCUPATION_TYPE with DAYS_EMPLOYED and TOTAL_DOC_SUBMITTED

# %%
sb.barplot(data = E,x = "DAYS_EMPLOYED", hue = "TOTAL_DOC_SUBMITTED", y = 'OCCUPATION_TYPE',estimator=np.mean)
plt.show()

# %%
sb.scatterplot(E["DAYS_EMPLOYED"],E['OCCUPATION_TYPE'],E['TOTAL_DOC_SUBMITTED'])
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED', ylabel='OCCUPATION_TYPE'>

# %% [markdown]
# #### Conclusion: Many of them have submitted single document

# %% [markdown]
# ### Analysis of the OCCUPATION_TYPE with DAYS_EMPLOYED and Monthly income

# %%
sb.scatterplot(E["DAYS_EMPLOYED"],E['OCCUPATION_TYPE'],E['AMT_INCOME_TOTAL'])
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED', ylabel='OCCUPATION_TYPE'>

# %% [markdown]
# #### Conclusion: Maximum clients have max income of 150000

# %% [markdown]
# ### Analysis of the Car with AMT_CREDIT and NAME_INCOME_TYPE

# %%
sb.scatterplot(df["AMT_CREDIT"],df['NAME_INCOME_TYPE'],df['Car'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='NAME_INCOME_TYPE'>

# %% [markdown]
# #### Conclusion: The client owns car have high amount creditted

# %% [markdown]
# ### Analysis of the House with AMT_CREDIT and NAME_INCOME_TYPE

# %%
sb.scatterplot(df["AMT_CREDIT"],df['NAME_INCOME_TYPE'],df['House'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='NAME_INCOME_TYPE'>

# %% [markdown]
# #### Conclusion: The client owns House and Pensioner have high amount creditted

# %% [markdown]
# ### Analysis of the AMT_CREDIT with AD and TOTAL_DOC_SUBMITTED

# %%
sb.scatterplot(df["AMT_CREDIT"],df['APPLICATION_DAY'],df['TOTAL_DOC_SUBMITTED'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='APPLICATION_DAY'>

# %% [markdown]
# ### Analysis of the AMT_CREDIT with Targets and Monthly income

# %%
sb.scatterplot(df["AMT_CREDIT"],df['AMT_INCOME_TOTAL'],df['TARGET'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='AMT_INCOME_TOTAL'>

# %% [markdown]
# #### Conclusion: As monthly income increases the amount credit also increases

# %% [markdown]
# ### Analysis of the AMT_CREDIT with income and FLAG_EMAIL

# %%
sb.scatterplot(df["AMT_CREDIT"],df['AMT_INCOME_TOTAL'],df['FLAG_EMAIL'])
# Out:
# <AxesSubplot:xlabel='AMT_CREDIT', ylabel='AMT_INCOME_TOTAL'>

# %% [markdown]
# #### Conclusion: High amount of clients have not given any email for irregularities of payment

# %% [markdown]
# Overall Conclusion
# ----------------------------------------------------------
# Low income with high credit amount comes under Defaulter \
# Most clients come under irregularities in payment \
# Pension clients should be considered as different section  \
# Due to above points the defaulters are the one who are not repaying the credit amount so the credit amount addition should be stopped for them \
